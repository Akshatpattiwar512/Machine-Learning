# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshatpattiwar512/Machine-Learning/blob/main/Keras_fashion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing mnist dataset
# !pip install keras
from keras.datasets import fashion_mnist
data=fashion_mnist.load_data()

# %%
(X_train,y_train), (X_test, y_test)=fashion_mnist.load_data()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Input, Dense
import numpy as np

# %%
x=np.array([[0,0], [0,1],[1,0], [1,1]],"uint8")
y=np.array([[0],[0],[0],[1]],"uint8")

# %%
model=Sequential()
model.add(Dense(units=1,activation="sigmoid",input_dim=2))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_41 (Dense)             (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x,y,epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 366ms/step - loss: 0.7446 - accuracy: 0.7500
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7442 - accuracy: 0.7500
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7438 - accuracy: 0.7500
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7434 - accuracy: 0.7500
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7430 - accuracy: 0.7500
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7426 - accuracy: 0.7500
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7422 - accuracy: 0.7500
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7418 - accuracy: 0.7500
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7414 - accuracy: 0.7500
# Epoch 10/1000
# ...

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train=X_train.reshape((X_train.shape[0],28*28)).astype('float32')
X_test=X_test.reshape((X_test.shape[0], 28*28)).astype('float32')

# %%
#Normalizing values from 0-255 to 0-1
X_train=X_train/255
X_test=X_test/255

# %%
from keras.utils import np_utils
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)
num_classes=y_test.shape[1]
num_classes
# Out:
# 10

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
model=Sequential()
model.add(Dense(32,input_dim=28*28,activation='relu')) #hidden layer 1
model.add(Dense(64,activation='relu'))                 #hidden layer 2
model.add(Dense(128,activation='relu'))                #hidden layer 3
model.add(Dense(256,activation='relu'))                #hidden layer 4
model.add(Dense(512,activation='relu'))                #hidden layer 5
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss="categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_42 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_45 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_46 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_47 (Dense)             (None, 10)                5130
# ...
# Total params: 205,290
# Trainable params: 205,290
# Non-trainable params: 0
# ...

# %%
model.fit(X_train,y_train,epochs=10,batch_size=200)
# Out:
# Epoch 1/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.3062 - accuracy: 0.8859
# Epoch 2/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2915 - accuracy: 0.8914
# Epoch 3/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2844 - accuracy: 0.8935
# Epoch 4/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2727 - accuracy: 0.8971
# Epoch 5/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2665 - accuracy: 0.8991
# Epoch 6/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2558 - accuracy: 0.9045
# Epoch 7/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2523 - accuracy: 0.9048
# Epoch 8/10
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2486 - accuracy: 0.9051
# Epoch 9/10
# 300/300 [==============================] - 3s 11ms/step - loss: 0.2374 - accuracy: 0.9104
# Epoch 10/10
# ...

# %%
scores=model.evaluate(X_test,y_test)
scores
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3654 - accuracy: 0.8769
# [0.36536914110183716, 0.8769000172615051]
